# %% [markdown]
# <a href="https://colab.research.google.com/github/Mjbloomf/MAT-421/blob/Main/Module_H_22_1%2C_22_2%2C_22_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Module H: 22.1, 22.2, 22.3**

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')
# %matplotlib inline

g = lambda t, s: np.cos(t) 
h1 = 0.3
t = np.arange(0, 1 + h1, h1) 
s0 = -1.0 


s = np.zeros(len(t))
s[0] = s0

for i in range(0, len(t) - 1):
    s[i + 1] = s[i] + h1*g(t[i], s[i])

plt.figure(figsize = (12, 8))
plt.plot(t, s, 'r--', label='Approximate')
plt.plot(t, -np.exp(-t), 'b', label='Exact')
plt.title('Approx and Ex Solution \
for Simple ODE')
plt.xlabel('t')
plt.ylabel('f(t)')
plt.grid()
plt.show()
